# %% [markdown]
# # `nb01`: Build, compute, critique, repeat

# %% [markdown]
# ![](./figures/nb01/boxloop.png)

# %% [markdown]
# # Build

# %% [markdown]
# Here I work on a simple example of modelisation: given
# - an initial momentum (speed)
# - the angle
# - the gravity
#
# Where does a ball fell on the ground?
#
#
# here is built the generative model, which generates the full trajectory

# %%
# Generative model
import numpy as np

def simulate(v, alpha, dt=0.001, G=9.81):
    v_x = v * np.cos(alpha)  # x velocity m/s
    v_y = v * np.sin(alpha)  # y velocity m/s
    
    x = 0.0  # initial position
    y = 1.5  # initial height
    trajectory = [(x, y)]

    while y > 0:  # simulate until ball hits floor
        v_y += dt * -G  # acceleration due to gravity
        x += dt * v_x
        y += dt * v_y
        trajectory.append((x, y))
        
    return np.array(trajectory)

# %%
import matplotlib.pyplot as plt

v = 5.0
alpha = np.pi / 4.0

trajectory = simulate(v, alpha)
plt.plot(trajectory[:, 0], trajectory[:, 1])
plt.show()

# %% [markdown]
# ## likehood
#
# the likehood function can be understood as the probability of observing the result value given the parameter

# %% [markdown]
# ### libraries for building a likehood
#
# at first scipy stats

# %%
# Probabilistic model
from scipy.stats import norm, uniform

# %%
 # observational model
def likelihood(v, alpha): 
    trajectory = simulate(v, alpha)
    x = trajectory[-1, 0]
    return norm(loc=x, scale=0.5)

# %% [markdown]
# ## prior models
#
# the prior models are the assumed probability distribution of the parameters

# %%
# prior model  
p_v = uniform(0., 10.0)    # start with [0,1] and discuss
p_alpha = uniform(0., np.pi / 2)   # start with [-pi;pi]

# %%
# p(x | v, alpha)
v = 5.0
alpha = np.pi / 4.0

trajectory = simulate(v, alpha)
plt.plot(trajectory[:, 0], trajectory[:, 1])

lk = likelihood(v, alpha)
xs = lk.rvs(10000)
plt.hist(xs, density=True, bins=30)

plt.show()

# %% [markdown]
# ## visualizing the results
#
# here is plotted the simuilated x_obs given the priors

# %%
# p(x)
xs = []

for i in range(1000):
    v = p_v.rvs()
    alpha = p_alpha.rvs()
    trajectory = simulate(v, alpha)
    plt.plot(trajectory[:, 0], trajectory[:, 1], color="b", alpha=0.05)
    x = likelihood(v, alpha).rvs()
    xs.append(x)
    
plt.hist(xs, density=True, bins=30, color="orange")
plt.show()

# %% [markdown]
# # Data

# %%
v_true = 5.0
alpha_true = np.pi / 4
x_obs = likelihood(v_true, alpha_true).rvs()

# %%
trajectory = simulate(v_true, alpha_true)
plt.plot(trajectory[:, 0], trajectory[:, 1])

lk = likelihood(v_true, alpha_true)
xs = lk.rvs(10000)
plt.hist(xs, density=True, bins=30)
plt.scatter([x_obs], [0.])
plt.show()

# %% [markdown]
# # Compute

# %%
# Point-valued estimate
from scipy.optimize import minimize

def log_likelihood(theta, x):
    v, alpha = theta
    lk = likelihood(v, alpha)
    return lk.logpdf(x)

nll = lambda *args: -log_likelihood(*args)
initial = np.array([p_v.rvs(), p_alpha.rvs()])
soln = minimize(nll, initial, args=(x_obs,))
soln
# Out:
#       fun: 0.22579135264473293
#  hess_inv: array([[0.99597193, 0.05666055],
#        [0.05666055, 0.00648304]])
#       jac: array([1.26659870e-07, 4.09781933e-07])
#   message: 'Optimization terminated successfully.'
#      nfev: 24
#       nit: 5
#      njev: 8
#    status: 0
#   success: True
#         x: array([6.54875543, 1.16566185])

# %%
v_sol, alpha_sol = soln.x

trajectory = simulate(v_sol, alpha_sol)
plt.plot(trajectory[:, 0], trajectory[:, 1])
plt.scatter([x_obs], [0.])

plt.show()

# %%
# Uncertainty estimation
def log_prior(theta):
    v, alpha = theta
    return p_v.logpdf(v) + p_alpha.logpdf(alpha)  
    
def log_posterior(theta, x):
    lp = log_prior(theta)
    if not np.isfinite(lp):
        return -np.inf
    return lp + log_likelihood(theta, x)

# %%
import emcee

pos = soln.x + 0.1 * np.random.randn(10, 2)
nwalkers, ndim = pos.shape

sampler = emcee.EnsembleSampler(nwalkers, ndim, log_posterior, args=(x_obs,))
sampler.run_mcmc(pos, 10000, progress=True);
# Out:
# 100%|█████████████████████████████████████| 10000/10000 [02:19<00:00, 71.44it/s]

# %%
fig, axes = plt.subplots(2, figsize=(10, 7), sharex=True)
samples = sampler.get_chain()
labels = ["v", "alpha"]

for i in range(ndim):
    ax = axes[i]
    ax.plot(samples[:, :, i], "k", alpha=0.3)
    ax.set_xlim(0, len(samples))
    ax.set_ylabel(labels[i])
    ax.yaxis.set_label_coords(-0.1, 0.5)

axes[-1].set_xlabel("step number")
plt.show()

# %%
import corner
thetas = sampler.get_chain(flat=True)
fig = corner.corner(thetas, labels=labels, truths=[v_true, alpha_true])

# %% [markdown]
# # Critique

# %%
# Computational diagnostics 
tau = sampler.get_autocorr_time()
print(tau)
# Out:
# [130.5005045  170.01246809]

# %%
thetas = sampler.get_chain(flat=True, discard=200, thin=50)
thetas.shape
# Out:
# (1960, 2)

# %%
fig = corner.corner(thetas, labels=labels, truths=[v_true, alpha_true])

# %%
# Posterior predictive checks
# p(x | x_obs)
xs = []
    
for v, alpha in thetas:
    trajectory = simulate(v, alpha)
    plt.plot(trajectory[:, 0], trajectory[:, 1], color="b", alpha=0.01)
    
    x = likelihood(v, alpha).rvs()
    xs.append(x)

plt.hist(xs, density=True, bins=30, color="orange")
plt.scatter([x_obs], [0.])
plt.show()

# %% [markdown]
# # Improve and repeat

# %% [markdown]
# - What if `x_obs=15`?
# - What if the height of the pitcher is unknown?
# - What if there is wind?
# - What if, maybe, there is wind?
# - How to evaluate and compare models?
